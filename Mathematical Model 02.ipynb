# %%
from docplex.mp.model import Model
import numpy as np 
import matplotlib.pyplot as plt 
import random

# Create a model
model = Model("minimization_problem")

# %%
# Define y and phiD(y)
y = model.continuous_var(name='y')

# %%
#Constants
cri=100
cod = 1000
x=0
n= 24
Budget_Demand = 100000
upper_limit = 24 #This will change when we implement probability distribution

# %%
#Variables
T = model.binary_var(name = 'T')
i = model.continuous_var(name = 'i')

# %%
#Defining Max Function
def Max_Function(i,y):
    return max(0,i-y)

# %%
#Objective_Formula
def object_function(y):
    return (sum(cri * y for i in range(n)) + sum (cod * Max_Function(i,y)for i in range(n) ))

# %%
#Constraint
#object_function() <= Budget_Demand
y <= upper_limit
# Out:
# docplex.mp.LinearConstraint[](y,LE,24)

# %%
# Set objective to minimize the objective function
model.minimize(object_function(y))

# Solve the model
model.solve()
sol=model.solve()
sol.display()

# Display the solution
print("Optimal solution:")
print("y =", y.solution_value)
print (object_function())
# Out:
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Cell In[204], line 2
#       1 # Set objective to minimize the objective function
# ----> 2 model.minimize(object_function(y))
#       4 # Solve the model
#       5 model.solve()
#
# Cell In[202], line 3, in object_function(y)
#       2 def object_function(y):
# ----> 3     return (sum(cri * y for i in range(n)) + sum (cod * Max_Function(i,y)for i in range(n) ))
#
# Cell In[202], line 3, in <genexpr>(.0)
#       2 def object_function(y):
# ----> 3     return (sum(cri * y for i in range(n)) + sum (cod * Max_Function(i,y)for i in range(n) ))
#
# Cell In[201], line 3, in Max_Function(i, y)
#       2 def Max_Function(i,y):
# ----> 3     return max(0,i-y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\docplex\mp\operand.py:156, in LinearOperand.__gt__(self, e)
#     155 def __gt__(self, e):
# --> 156     self.model.unsupported_relational_operator_error(self, ">", e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\docplex\mp\model.py:266, in Model.unsupported_relational_operator_error(self, left_arg, op, right_arg)
#     264 def unsupported_relational_operator_error(self, left_arg, op, right_arg):
#     265     # INTERNAL
# --> 266     self.fatal("Unsupported relational operator:  {0!s} {1!s} {2!s}, only <=, ==, >= are allowed", left_arg, op,
#     267                right_arg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\docplex\mp\model.py:1080, in Model.fatal(self, msg, *args)
#    1079 def fatal(self, msg, *args):
# -> 1080     self._error_handler.fatal(msg, args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Unsupported relational operator:  -y > 0, only <=, ==, >= are allowed
